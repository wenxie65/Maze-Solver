# %%
# %run dfs.ipynb
# %run ../Random-Maze-Generator/maze.ipynb

# %%
maze = Maze(20,40)
maze.generate_maze()
maze.display_maze()

# %%
# Test dfs solver
path = dfs_solver(maze)
maze.display_maze(solution = path)
