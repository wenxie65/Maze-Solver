# %%
# %run dfs.ipynb
# %run bfs.ipynb
# %run a_star.ipynb
# %run ../Random-Maze-Generator/maze.ipynb

# %%
maze = Maze(20, 40)
maze.generate_maze()
maze.display_maze()

# %%
# Test dfs solver
dfs_path = dfs_solver(maze)
maze.display_maze(solution = dfs_path)

# %%
# Test bfs solver
bfs_path = bfs_solver(maze)
maze.display_maze(solution = bfs_path)

# %%
# test a* solver
came_from = a_star_solver(maze)
a_star_path = get_solution(maze, came_from)
maze.display_maze(solution = a_star_path)
